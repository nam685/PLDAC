# %% [markdown]
# # Recherche d'information : librairie PyTerrier
#
# Dans cette partie, nous nous intéressons à la librairie [PyTerrier](https://pyterrier.readthedocs.io/en/latest/#) qui permet de mettre en place diverses briques d'un moteur de recherche.
# PyTerrier est basée sur [Terrier](http://terrier.org/) qui est un moteur de recherche développé en Java.
#
# Nous allons voir :
# *   l'installation et la configuration
# *   l'indexation d'une collection
# *   l'accès à l'index
# *   l'évaluation d'un moteur de recherche

# %% [markdown]
# ## Installation ete configuration
#
# Après l'installation de la librairie, il est nécessaire d'initialiser PyTerrier pour importer les fichiers jar et démarrer la machine virtuelle associée;

# %%
# !pip install python-terrier

import pyterrier as pt
if not pt.started():
    pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])
# Out:
# Collecting python-terrier
#   Downloading python-terrier-0.8.0.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 5.2 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.3.5)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from python-terrier) (4.62.3)
# Collecting pyjnius~=1.3.0
#   Downloading pyjnius-1.3.0-cp37-cp37m-manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 61.1 MB/s
# Collecting matchpy
#   Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 8.4 MB/s
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.0)
# Collecting deprecation
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting chest
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.23.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.1.0)
# Collecting nptyping
#   Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.7/dist-packages (from python-terrier) (8.12.0)
# Collecting ir_datasets>=0.3.2
#   Downloading ir_datasets-0.5.0-py3-none-any.whl (255 kB)
#      |████████████████████████████████| 255 kB 57.4 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.11.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.10.2)
# Collecting ir_measures>=0.2.0
#   Downloading ir_measures-0.2.3.tar.gz (41 kB)
#      |████████████████████████████████| 41 kB 317 kB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.3.4)
# Collecting lz4>=3.1.1
#   Downloading lz4-3.1.10-cp37-cp37m-manylinux2010_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 21.0 MB/s
# Collecting pyautocorpus>=0.1.1
#   Downloading pyautocorpus-0.1.8-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 72.9 MB/s
# Collecting pyyaml>=5.3.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 55.4 MB/s
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.6.3)
# Collecting warc3-wet>=0.2.3
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Collecting trec-car-tools>=2.5.4
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting lxml>=4.5.2
#   Downloading lxml-4.7.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 66.2 MB/s
# Collecting zlib-state>=0.1.3
#   Downloading zlib_state-0.1.5-cp37-cp37m-manylinux2010_x86_64.whl (72 kB)
#      |████████████████████████████████| 72 kB 1.6 MB/s
# Collecting ijson>=3.1.3
#   Downloading ijson-3.1.4-cp37-cp37m-manylinux2010_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 75.1 MB/s
# Collecting warc3-wet-clueweb09>=0.2.5
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
# Collecting pytrec-eval-terrier==0.5.1
#   Downloading pytrec_eval_terrier-0.5.1-cp37-cp37m-manylinux2010_x86_64.whl (291 kB)
#      |████████████████████████████████| 291 kB 74.9 MB/s
# Collecting cwl-eval>=1.0.10
#   Downloading cwl-eval-1.0.10.tar.gz (31 kB)
# Collecting pyndeval>=0.0.2
#   Downloading pyndeval-0.0.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (59 kB)
#      |████████████████████████████████| 59 kB 7.8 MB/s
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from pyjnius~=1.3.0->python-terrier) (0.29.27)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from pyjnius~=1.3.0->python-terrier) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (1.24.3)
# Collecting cbor>=1.0.0
#   Downloading cbor-1.0.0.tar.gz (20 kB)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from deprecation->python-terrier) (21.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->python-terrier) (2.0.1)
# Collecting multiset<3.0,>=2.0
#   Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Collecting typish>=1.7.0
#   Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.7 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->deprecation->python-terrier) (3.0.7)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->python-terrier) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->python-terrier) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->python-terrier) (3.1.0)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->python-terrier) (0.5.2)
# Building wheels for collected packages: python-terrier, ir-measures, cwl-eval, cbor, warc3-wet-clueweb09, chest, wget
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.8.0-py3-none-any.whl size=103883 sha256=5e49cd7d94ca5cd8b8f35512bd6a5fd7f69a56df730776eb0b38dc6cb0c98197
#   Stored in directory: /root/.cache/pip/wheels/a8/ec/0c/fd9fcb409ad158d1f62534f9b1924b406f420f1a4170fb4132
#   Building wheel for ir-measures (setup.py) ... done
#   Created wheel for ir-measures: filename=ir_measures-0.2.3-py3-none-any.whl size=53217 sha256=bfdcfeee44f20fb33f28124c94b1a7adf16f43cb05ba43966f0a357aa27d81b4
#   Stored in directory: /root/.cache/pip/wheels/b2/06/1b/b8dc2d9a9802a9c30dd3a28d4199061297df0034d8ab9b808a
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.10-py3-none-any.whl size=37797 sha256=7a5707ddef174ef2bf2555f974e014e6f366d15ef8c7d3f1d16a7817a88bee07
#   Stored in directory: /root/.cache/pip/wheels/ff/e9/ff/d2b6d72d9feb0d0b1b11aacfaf5cd866717034615c2d194093
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp37-cp37m-linux_x86_64.whl size=51309 sha256=de1f59f872523a900d07f8b87dfaf63f4c70c629edccadc045c9187d53cdec6f
#   Stored in directory: /root/.cache/pip/wheels/19/77/49/c9c2c8dc5848502e606e8579d0bbda18b850fb056a6c62239d
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18922 sha256=235803477f3efc60952b690c0e3b48daa13fff7bcd529a1f6a483894c2978b3e
#   Stored in directory: /root/.cache/pip/wheels/42/d4/3c/7c2b0c3d400ad744e4db69f2fde166655da2ed2198bfc02db6
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7634 sha256=28f7602b6b8bed814def1145dd74b1f1b1736daba82f3d362984e863756bc3f3
#   Stored in directory: /root/.cache/pip/wheels/fc/f5/b9/c436e11300809e6b40d46a5d2592fb0bff89e0712f2e878dc7
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=e2e985b0387b454c7fbfc1b1f1a5056463f1e31423fbf882cfe469946cf26e38
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built python-terrier ir-measures cwl-eval cbor warc3-wet-clueweb09 chest wget
# Installing collected packages: cbor, zlib-state, warc3-wet-clueweb09, warc3-wet, typish, trec-car-tools, pyyaml, pytrec-eval-terrier, pyndeval, pyautocorpus, multiset, lz4, lxml, ijson, cwl-eval, wget, pyjnius, nptyping, matchpy, ir-measures, ir-datasets, deprecation, chest, python-terrier
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed cbor-1.0.0 chest-0.2.3 cwl-eval-1.0.10 deprecation-2.1.0 ijson-3.1.4 ir-datasets-0.5.0 ir-measures-0.2.3 lxml-4.7.1 lz4-3.1.10 matchpy-0.5.5 multiset-2.1.1 nptyping-1.4.4 pyautocorpus-0.1.8 pyjnius-1.3.0 pyndeval-0.0.2 python-terrier-0.8.0 pytrec-eval-terrier-0.5.1 pyyaml-6.0 trec-car-tools-2.6 typish-1.9.3 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wget-3.2 zlib-state-0.1.5
# terrier-assemblies 5.6 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.6 jar not found, downloading to /root/.pyterrier...
# Done
# terrier-prf -SNAPSHOT jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.8.0 has loaded Terrier 5.6 (built by craigmacdonald on 2021-09-17 13:27)

# %% [markdown]
# ## Indexation d'une collection
#
# Il est possible d'indexer plusieurs formats de collection : format TREC, fichiers en texte brut ou en PDF, ou encore des Dataframe Pandas ([pour plus de détails](https://pyterrier.readthedocs.io/en/latest/terrier-indexing.html)).
#
# Un petit exemple à titre illustratif est foourni dans le code suivant :

# %%
import pandas as pd

# configuration de l'affichage
pd.set_option('display.max_colwidth', 150)

# le jeu de données au format DataFrame
docs_df = pd.DataFrame([
        ["d1", "this is the first document of many documents"],
        ["d2", "this is another document"],
        ["d3", "the topic of this document is unknown"]
    ], columns=["docno", "text"])

# création de l'index
indexer = pt.DFIndexer("./index_3docs", overwrite=True)         # Définition du format de données (DFIndexer())
index_ref = indexer.index(docs_df["text"], docs_df["docno"])    # Indexation des champs text et docno
# !ls -lh index_3docs/                                            # Affichage de l'index sauvegardé dans "./index_3docs/"
# Out:
# total 40K
# -rw-r--r-- 1 root root    3 Feb  8 08:58 data.direct.bf
# -rw-r--r-- 1 root root   51 Feb  8 08:58 data.document.fsarrayfile
# -rw-r--r-- 1 root root    4 Feb  8 08:58 data.inverted.bf
# -rw-r--r-- 1 root root  344 Feb  8 08:58 data.lexicon.fsomapfile
# -rw-r--r-- 1 root root  249 Feb  8 08:58 data.lexicon.fsomaphash
# -rw-r--r-- 1 root root   33 Feb  8 08:58 data.meta-0.fsomapfile
# -rw-r--r-- 1 root root   24 Feb  8 08:58 data.meta.idx
# -rw-r--r-- 1 root root   48 Feb  8 08:58 data.meta.zdata
# -rw-r--r-- 1 root root 4.1K Feb  8 08:58 data.properties

# %% [markdown]
# De nombreux fichiers sont créés : index direct, index inverse, méta-données de l'index et de la configuration de l'indexation, etc...
#
#
# Il est également possible de modifier la configuration de l'indexation : [voir ici](https://pyterrier.readthedocs.io/en/latest/terrier-indexing.html#indexing-configuration).
#
# Pour chager un index existant en local :

# %%
index = pt.IndexFactory.of(index_ref)

# %% [markdown]
# Il est aussi possible de voir les statistiques de l'index.
# pour connaître toutes les fonctions d'interrogation, se référencer à la [javadoc](http://terrier.org/docs/current/javadoc/org/terrier/structures/Index.html).

# %%
# statistiques de la collection
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 3
# Number of terms: 4
# Number of postings: 6
# Number of fields: 0
# Number of tokens: 7
# Field names: []
# Positions:   false

# %%
# statistiques du vocabulaire.
# Nt : document frequency : nombre de documents contenant le terme
# TF : term frequency : nombre d'occurences du terme
# maxTF : nombre d'occurences maximal pour un document
for kv in index.getLexicon():
  print("%s (%s) -> %s (%s)" % (kv.getKey(), type(kv.getKey()), kv.getValue().toString(), type(kv.getValue()) ) )
# Out:
# document (<class 'str'>) -> term0 Nt=3 TF=4 maxTF=2 @{0 0 0} (<class 'jnius.reflect.org.terrier.structures.LexiconEntry'>)
# first (<class 'str'>) -> term1 Nt=1 TF=1 maxTF=1 @{0 0 7} (<class 'jnius.reflect.org.terrier.structures.LexiconEntry'>)
# topic (<class 'str'>) -> term2 Nt=1 TF=1 maxTF=1 @{0 1 1} (<class 'jnius.reflect.org.terrier.structures.LexiconEntry'>)
# unknown (<class 'str'>) -> term3 Nt=1 TF=1 maxTF=1 @{0 1 5} (<class 'jnius.reflect.org.terrier.structures.LexiconEntry'>)

# %%
# focus sur un terme particulier
index.getLexicon()["document"].toString()
# Out:
# 'term0 Nt=3 TF=4 maxTF=2 @{0 0 0}'

# %%
# récupère les statistiques de l'index inverse à partir d'un terme particulier
pointer = index.getLexicon()["document"]
for posting in index.getInvertedIndex().getPostings(pointer):
    print(posting.toString() + " doclen=%d" % posting.getDocumentLength())
# Out:
# ID(0) TF(2) doclen=3
# ID(1) TF(1) doclen=1
# ID(2) TF(1) doclen=3

# %% [markdown]
# De plus, PyTerrier met à disposition [une collection de jeux de données pré-traités](https://pyterrier.readthedocs.io/en/latest/datasets.html).
# Dans ce qui suit, nous allons nous concentrer sur le jeu de données CORD19 qui recense des articles liés à la crise sanitaire Covid-19. Il est

# %%
import os

cord19 = pt.datasets.get_dataset('irds:cord19/trec-covid')
pt_index_path = './terrier_cord19'

if not os.path.exists(pt_index_path + "/data.properties"):
  # création de l'index. Utilisation de l'itérateur pour parcourir la collection
  indexer = pt.index.IterDictIndexer(pt_index_path)

  # on donne à l'index la fonction pour parcourir l'index avec l'itérateur  get_corpus_iter() 
  # On spécifie les champs à indexer et les meta-données à sauvegarder
  index_ref = indexer.index(cord19.get_corpus_iter(), 
                            fields=('abstract',), 
                            meta=('docno',))

else:
  # dans le cas où l'index existe déjà
  index_ref = pt.IndexRef.of(pt_index_path + "/data.properties")
index = pt.IndexFactory.of(index_ref)
# Out:
# [INFO] [starting] building docstore
# [INFO] If you have a local copy of https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv, you can symlink it here to avoid downloading it again: /root/.ir_datasets/downloads/80d664e496b8b7e50a39c6f6bb92e0ef
# [INFO] [starting] https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv
# docs_iter:   0%|                                    | 0/192509 [00:00<?, ?doc/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.0%| 0.00/269M [00:00<?, ?B/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.0%| 24.6k/269M [00:00<29:45, 151kB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.0%| 57.3k/269M [00:00<26:07, 172kB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.0%| 106k/269M [00:00<21:19, 210kB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.1%| 229k/269M [00:00<13:16, 338kB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.2%| 492k/269M [00:00<07:46, 577kB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.4%| 1.02M/269M [00:01<04:30, 990kB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.8%| 2.06M/269M [00:01<02:35, 1.72MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 1.5%| 4.14M/269M [00:01<01:27, 3.02MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 2.3%| 6.22M/269M [00:01<01:05, 4.02MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 3.1%| 8.30M/269M [00:01<00:54, 4.83MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 3.9%| 10.4M/269M [00:01<00:47, 5.49MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 4.6%| 12.5M/269M [00:02<00:42, 6.03MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 5.4%| 14.5M/269M [00:02<00:39, 6.50MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 6.2%| 16.6M/269M [00:02<00:36, 6.89MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 6.9%| 18.7M/269M [00:02<00:34, 7.24MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 7.7%| 20.8M/269M [00:02<00:32, 7.54MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 8.5%| 22.9M/269M [00:02<00:31, 7.80MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 9.3%| 24.9M/269M [00:03<00:30, 8.04MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 10.0%| 27.0M/269M [00:03<00:29, 8.25MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 10.8%| 29.1M/269M [00:03<00:28, 8.44MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 11.6%| 31.2M/269M [00:03<00:27, 8.61MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 12.4%| 33.3M/269M [00:03<00:26, 8.79MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 13.2%| 35.5M/269M [00:03<00:26, 8.95MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 14.0%| 37.6M/269M [00:04<00:25, 9.09MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 14.8%| 39.8M/269M [00:04<00:24, 9.22MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 15.6%| 41.9M/269M [00:04<00:24, 9.34MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 16.4%| 44.1M/269M [00:04<00:23, 9.45MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 17.2%| 46.2M/269M [00:04<00:23, 9.56MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 18.0%| 48.4M/269M [00:05<00:22, 9.66MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 18.8%| 50.5M/269M [00:05<00:22, 9.75MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 19.6%| 52.6M/269M [00:05<00:22, 9.84MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 20.4%| 54.9M/269M [00:05<00:21, 9.94MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 21.3%| 57.3M/269M [00:05<00:21, 10.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 22.2%| 59.8M/269M [00:05<00:20, 10.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 23.1%| 62.2M/269M [00:06<00:20, 10.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 24.0%| 64.6M/269M [00:06<00:19, 10.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 24.9%| 67.0M/269M [00:06<00:19, 10.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 25.8%| 69.5M/269M [00:06<00:18, 10.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 26.7%| 71.9M/269M [00:06<00:18, 10.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 27.6%| 74.3M/269M [00:06<00:18, 10.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 28.5%| 76.7M/269M [00:07<00:17, 10.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 29.4%| 79.2M/269M [00:07<00:17, 10.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 30.3%| 81.6M/269M [00:07<00:17, 11.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 31.2%| 84.0M/269M [00:07<00:16, 11.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 32.1%| 86.4M/269M [00:07<00:16, 11.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 33.0%| 88.9M/269M [00:07<00:16, 11.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 33.9%| 91.3M/269M [00:08<00:15, 11.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 34.8%| 93.7M/269M [00:08<00:15, 11.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 35.7%| 96.1M/269M [00:08<00:15, 11.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 36.6%| 98.6M/269M [00:08<00:14, 11.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 37.5%| 101M/269M [00:08<00:14, 11.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 38.4%| 103M/269M [00:08<00:14, 11.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 39.3%| 106M/269M [00:09<00:14, 11.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 40.2%| 108M/269M [00:09<00:13, 11.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 41.1%| 111M/269M [00:09<00:13, 11.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 42.0%| 113M/269M [00:09<00:13, 11.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 42.9%| 116M/269M [00:09<00:13, 11.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 43.8%| 118M/269M [00:10<00:12, 11.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 44.7%| 120M/269M [00:10<00:12, 11.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 45.6%| 123M/269M [00:10<00:12, 11.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 46.5%| 125M/269M [00:10<00:12, 11.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 47.4%| 128M/269M [00:10<00:11, 11.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 48.3%| 130M/269M [00:10<00:11, 11.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 49.2%| 133M/269M [00:11<00:11, 12.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 50.1%| 135M/269M [00:11<00:11, 12.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 51.0%| 137M/269M [00:11<00:10, 12.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 51.9%| 140M/269M [00:11<00:10, 12.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 52.9%| 142M/269M [00:11<00:10, 12.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 53.8%| 145M/269M [00:11<00:10, 12.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 54.7%| 147M/269M [00:12<00:10, 12.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 55.7%| 150M/269M [00:12<00:09, 12.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 56.6%| 152M/269M [00:12<00:09, 12.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 57.5%| 155M/269M [00:12<00:09, 12.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 58.5%| 157M/269M [00:12<00:09, 12.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 59.4%| 160M/269M [00:12<00:08, 12.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 60.4%| 162M/269M [00:13<00:08, 12.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 61.3%| 165M/269M [00:13<00:08, 12.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 62.2%| 168M/269M [00:13<00:08, 12.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 63.2%| 170M/269M [00:13<00:07, 12.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 64.1%| 173M/269M [00:13<00:07, 12.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 65.0%| 175M/269M [00:14<00:07, 12.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 66.0%| 178M/269M [00:14<00:07, 12.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 66.9%| 180M/269M [00:14<00:07, 12.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 67.9%| 183M/269M [00:14<00:06, 12.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 68.8%| 185M/269M [00:14<00:06, 12.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 69.7%| 188M/269M [00:14<00:06, 12.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 70.7%| 190M/269M [00:15<00:06, 12.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 71.6%| 193M/269M [00:15<00:06, 12.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 72.5%| 195M/269M [00:15<00:05, 12.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 73.5%| 198M/269M [00:15<00:05, 12.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 74.4%| 200M/269M [00:15<00:05, 12.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 75.4%| 203M/269M [00:15<00:05, 12.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 76.3%| 205M/269M [00:16<00:04, 12.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 77.2%| 208M/269M [00:16<00:04, 12.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 78.2%| 210M/269M [00:16<00:04, 12.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 79.1%| 213M/269M [00:16<00:04, 12.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 80.0%| 215M/269M [00:16<00:04, 12.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 81.0%| 218M/269M [00:16<00:03, 12.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 81.9%| 221M/269M [00:17<00:03, 12.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 83.0%| 223M/269M [00:17<00:03, 12.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 84.0%| 226M/269M [00:17<00:03, 13.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 85.1%| 229M/269M [00:17<00:03, 13.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 86.1%| 232M/269M [00:17<00:02, 13.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 87.1%| 235M/269M [00:17<00:02, 13.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 88.2%| 237M/269M [00:18<00:02, 13.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 89.2%| 240M/269M [00:18<00:02, 13.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 90.3%| 243M/269M [00:18<00:01, 13.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 91.3%| 246M/269M [00:18<00:01, 13.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 92.4%| 249M/269M [00:18<00:01, 13.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 93.4%| 252M/269M [00:19<00:01, 13.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 94.5%| 254M/269M [00:19<00:01, 13.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 95.5%| 257M/269M [00:19<00:00, 13.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 96.6%| 260M/269M [00:19<00:00, 13.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 97.6%| 263M/269M [00:19<00:00, 13.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 98.7%| 266M/269M [00:19<00:00, 13.4MB/s]
#
# [INFO] [finished] https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: [00:20] [269MB] [13.4MB/s]
# docs_iter:   0%|                                    | 0/192509 [00:20<?, ?doc/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: [00:20] [269MB] [13.4MB/s]
# docs_iter: 100%|█████████████████████| 192509/192509 [00:33<00:00, 5782.85doc/s]
# [INFO] [finished] docs_iter: [00:33] [192509doc] [5782.62doc/s]
# [INFO] [finished] building docstore [33.30s]
# cord19/trec-covid documents:   0%|          | 0/192509 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: specifying meta and meta_lengths in IterDictIndexer.index() is deprecated, use constructor instead
# 09:14:48.615 [ForkJoinPool-1-worker-3] WARN org.terrier.structures.indexing.Indexer - Adding an empty document to the index (6iu1dtyl) - further warnings are suppressed
# 09:16:03.126 [ForkJoinPool-1-worker-3] WARN org.terrier.structures.indexing.Indexer - Indexed 54937 empty documents
# 09:16:03.240 [ForkJoinPool-1-worker-3] ERROR org.terrier.structures.indexing.Indexer - Could not finish MetaIndexBuilder:
# java.io.IOException: Key 8lqzfj2e is not unique: 37597,11755
# For MetaIndex, to suppress, set metaindex.compressed.reverse.allow.duplicates=true
# 	at org.terrier.structures.collections.FSOrderedMapFile$MultiFSOMapWriter.mergeTwo(FSOrderedMapFile.java:1374)
# 	at org.terrier.structures.collections.FSOrderedMapFile$MultiFSOMapWriter.close(FSOrderedMapFile.java:1308)
# 	at org.terrier.structures.indexing.BaseMetaIndexBuilder.close(BaseMetaIndexBuilder.java:321)
# 	at org.terrier.structures.indexing.classical.BasicIndexer.createDirectIndex(BasicIndexer.java:346)
# 	at org.terrier.structures.indexing.Indexer.index(Indexer.java:369)
# 	at org.terrier.python.ParallelIndexer$1.apply(ParallelIndexer.java:63)
# 	at org.terrier.python.ParallelIndexer$1.apply(ParallelIndexer.java:52)
# 	at java.base/java.util.stream.ReferencePipeline$3$1.accept(ReferencePipeline.java:195)
# 	at java.base/java.util.Spliterators$ArraySpliterator.forEachRemaining(Spliterators.java:948)
# 	at java.base/java.util.stream.AbstractPipeline.copyInto(AbstractPipeline.java:484)
# 	at java.base/java.util.stream.AbstractPipeline.wrapAndCopyInto(AbstractPipeline.java:474)
# 	at java.base/java.util.stream.ReduceOps$ReduceTask.doLeaf(ReduceOps.java:952)
# 	at java.base/java.util.stream.ReduceOps$ReduceTask.doLeaf(ReduceOps.java:926)
# 	at java.base/java.util.stream.AbstractTask.compute(AbstractTask.java:327)
# 	at java.base/java.util.concurrent.CountedCompleter.exec(CountedCompleter.java:746)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:290)
# 	at java.base/java.util.concurrent.ForkJoinTask.doInvoke(ForkJoinTask.java:408)
# 	at java.base/java.util.concurrent.ForkJoinTask.invoke(ForkJoinTask.java:736)
# 	at java.base/java.util.stream.ReduceOps$ReduceOp.evaluateParallel(ReduceOps.java:919)
# 	at java.base/java.util.stream.AbstractPipeline.evaluate(AbstractPipeline.java:233)
# 	at java.base/java.util.stream.ReferencePipeline.reduce(ReferencePipeline.java:558)
# 	at org.terrier.python.ParallelIndexer$3.call(ParallelIndexer.java:133)
# 	at org.terrier.python.ParallelIndexer$3.call(ParallelIndexer.java:130)
# 	at java.base/java.util.concurrent.ForkJoinTask$AdaptedCallable.exec(ForkJoinTask.java:1448)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:290)
# 	at java.base/java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1020)
# 	at java.base/java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1656)
# 	at java.base/java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1594)
# 	at java.base/java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:183)

# %% [markdown]
# **Exercice 1**
#
# Afficher les statistiques de l'index Cord19 et analyser statistiques du terme "tv" (pas trop fréquent pour question d'affichage).

# %%
print(index.collectionStatistics.toString())
# Out:
# Number of documents: 3
# Number of terms: 4
# Number of postings: 6
# Number of fields: 0
# Number of tokens: 7
# Field names: []
# Positions:   false

# %%
print(index.getLexicon()["work"])
print(index.getLexicon()["tv"])
# Out:
# term966 Nt=9936 TF=13505 maxTF=2147483647 @{0 19567749 0} TFf=13505
# term18759 Nt=70 TF=180 maxTF=2147483647 @{0 18614194 0} TFf=180

# %% [markdown]
# ## Recherche de documents à partir de l'index
#
# Pour effectuer une recherche dans l'index, il faut utiliser la fonction batchRetrieve qui prend en paramètre l'index et le modèle de pondération (tf, tf-idf, etc...). La liste des modèles supportés est disponible [ici](http://terrier.org/docs/current/javadoc/org/terrier/matching/models/package-summary.html).

# %%
br = pt.BatchRetrieve(index, wmodel="Tf")
br.search("chemical reactions")
# Out:
#     qid   docid     docno  rank  score               query
# 0     1   12409  ij3ncdb6     0   21.0  chemical reactions
# 1     1   24432  094bk0t0     1   13.0  chemical reactions
# 2     1   11268  qroxmo85     2   12.0  chemical reactions
# 3     1  120041  pb00yr0r     3   12.0  chemical reactions
# 4     1  147193  ei4rb8fr     4   12.0  chemical reactions
# ..   ..     ...       ...   ...    ...                 ...
# 995   1   96252  8clnrlec   995    2.0  chemical reactions
# 996   1   96758  rvw94nsg   996    2.0  chemical reactions
# 997   1   97138  lrx94c81   997    2.0  chemical reactions
# 998   1   98181  w3160mgp   998    2.0  chemical reactions
# 999   1   98642  dhoyiqtx   999    2.0  chemical reactions
#
# [1000 rows x 6 columns]

# %% [markdown]
# On récupère alors un DataFrame dont les colonnes sont les suivantes :
# *   qid : identifiant de la requête. Par défaut, il s'agit de "1", puisqu'il s'agit de notre première et unique requête.
# *   docid : l'identifiant interne de Terrier pour chaque document
# *   docno : l'identifiant unique externe (chaîne de caractères) pour chaque document
# *   score : score des documents selon le modèle choisi (ici : fréquence totale des tf des termes de la requête dans chaque document)
# *   rank : rang du document dénotant l'ordre décroissant par score.
# *   query : la requête d'entrée

# %%
# autre exemple de modèle : TF-IDF
tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
tfidf.search("chemical reactions")
# Out:
#     qid   docid     docno  rank      score               query
# 0     1   18717  iavwkdpr     0  11.035982  chemical reactions
# 1     1  171636  v3blnh02     1  10.329726  chemical reactions
# 2     1  147193  ei4rb8fr     2  10.317138  chemical reactions
# 3     1  121217  msdycum2     3   9.653734  chemical reactions
# 4     1  170863  sj8i9ss2     4   9.500211  chemical reactions
# ..   ..     ...       ...   ...        ...                 ...
# 995   1    2428  38aabxh1   995   3.790183  chemical reactions
# 996   1   14752  u709r8ss   996   3.790183  chemical reactions
# 997   1   20074  wxi1xsbo   997   3.790183  chemical reactions
# 998   1  117156  ts3obwts   998   3.790183  chemical reactions
# 999   1  149517  6i3x49p8   999   3.790183  chemical reactions
#
# [1000 rows x 6 columns]

# %% [markdown]
# On peut aussi fournir plusieurs requêtes grâce à un dataFrame. Pour interroger l'index, on applique la fonction transform() au BatchRetriever (br).
# pour plus de détails, voir [les propriétés des transformations](https://pyterrier.readthedocs.io/en/latest/transformer.html) ainsi que les [opérations possibles](https://pyterrier.readthedocs.io/en/latest/operators.html).

# %%
import pandas as pd
queries = pd.DataFrame([["q1", "document"], ["q2", "first document"]], columns=["qid", "query"])
br.transform(queries)       # ou aussi : br(queries)
# Out:
#      qid   docid     docno  rank  score           query
# 0     q1   14569  mm7gxjf1     0   12.0        document
# 1     q1  137615  duxm9u8v     1   12.0        document
# 2     q1   18789  x3o3a45b     2   10.0        document
# 3     q1  189505  hxp258y8     3   10.0        document
# 4     q1   37445  q5wglpoj     4    9.0        document
# ...   ..     ...       ...   ...    ...             ...
# 1995  q2  137347  xye8pgzt   995    3.0  first document
# 1996  q2  137487  k0y0fz7k   996    3.0  first document
# 1997  q2  138448  ut3ayexx   997    3.0  first document
# 1998  q2  138807  fulh7trp   998    3.0  first document
# 1999  q2  139327  2a84u4tm   999    3.0  first document
#
# [2000 rows x 6 columns]

# %% [markdown]
# **Exercice 2**
#
# Ordonnancer les documents pour 3 requêtes : "covid disease", "hospital" et "home".
# La fonction d'ordonnacement devra être de la forme suivante :
#
#
# ```
# 0.4 * score_Bm25 + 0.6 * score_Dirichlet
# ```

# %%
queries = pd.DataFrame([["q1", "covid disease"], ["q2", "hospital"], ["q3", "home"]], columns=["qid", "query"])
custom = 0.4 * pt.BatchRetrieve(index, wmodel="BM25") + 0.6 * pt.BatchRetrieve(index, wmodel="DirichletLM")
custom.transform(queries)
# Out:
#      qid     docid     docno     score          query  rank
# 0     q1   43498.0  9d8go2sl  3.067285  covid disease     1
# 1     q1  106017.0  a0w3n30z  3.067285  covid disease     2
# 2     q1  106018.0  smyp9fyo  3.067285  covid disease     3
# 3     q1  106019.0  vtfn9y5p  3.067285  covid disease     4
# 4     q1  158611.0  30ff3xg2  3.370553  covid disease     0
# ...   ..       ...       ...       ...            ...   ...
# 4216  q3       NaN  h5iew8oo  1.011830            NaN  1222
# 4217  q3       NaN  x7or04u6  0.989607            NaN  1223
# 4218  q3       NaN  i8litb66  0.987562            NaN  1224
# 4219  q3       NaN  i1gdsiw6  0.982324            NaN  1225
# 4220  q3       NaN  o0mhzx3g  0.952669            NaN  1226
#
# [4221 rows x 6 columns]

# %% [markdown]
# **Excercice 3**
#
# Créez un ordonnanceur qui effectue les opérations suivantes :
# * obtient les 10 documents les mieux notés par fréquence de terme (wmodel="Tf")
# * obtenir les 10 documents les mieux notés par TF.IDF (wmodel="TF_IDF")
# * ré-ordonne uniquement les documents trouvés dans les DEUX paramètres de recherche précédents en utilisant BM25.
#
# Combien de documents sont récupérés par ce pipeline complet pour la requête "chemical"?
#
# Vérification : le document avec le docno "37771" devrait avoir un score de 12.426309 $ pour la requête "chemical".

# %%
tf = pt.BatchRetrieve(index, wmodel="Tf")
tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
bm25 = pt.BatchRetrieve(index, wmodel="BM25")
pipe = (tf & tfidf) >> bm25
queries = pd.DataFrame([["q1", "chemical"]], columns=["qid", "query"])
pipe.transform(queries)
# Out:
#     qid   docid     docno  rank      score     query
# 0    q1   37771  jn5qi1jb     0  12.426309  chemical
# 1    q1   15671  8hykq71k     1  12.413269  chemical
# 2    q1  134305  0smev8vt     2  12.292890  chemical
# 3    q1  142104  77c9ohxj     3  12.226076  chemical
# 4    q1   87642  ck6clsty     4  12.155804  chemical
# ..   ..     ...       ...   ...        ...       ...
# 623  q1   48979  oc70u8d7   623   6.065540  chemical
# 624  q1    4713  gve33v4t   624   6.040683  chemical
# 625  q1    9767  pcu5sy6t   625   6.040683  chemical
# 626  q1   35909  xic0qqio   626   6.040683  chemical
# 627  q1   45510  i5z4yq4p   627   6.040683  chemical
#
# [628 rows x 6 columns]

# %% [markdown]
# ## Reformulation de requêtes
#
# Il est également possible de mettre en place des pipelines de [reformulation de requêtes](https://pyterrier.readthedocs.io/en/latest/rewrite.html).

# %%
bo1 = pt.rewrite.Bo1QueryExpansion(index)
dph = pt.BatchRetrieve(index, wmodel="DPH")
pipeline = dph >> bo1 >> dph
pipeline.search("chemical reactions")
# Out:
#     qid  ...                                                                                                                                                  query
# 0     1  ...  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 1     1  ...  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 2     1  ...  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 3     1  ...  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 4     1  ...  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# ..   ..  ...                                                                                                                                                    ...
# 995   1  ...  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 996   1  ...  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 997   1  ...  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 998   1  ...  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 999   1  ...  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
#
# [1000 rows x 7 columns]

# %% [markdown]
# L'autre solution est de l'intégrer directement dans la fonction d'ordonnancement. Mais la requête reformulée n'est pas visible et la solution précédente fait prendre conscience de la pipeline faite par le système de RI (ranking >> reformulation >> ranking quand on utilise des modèles basés sur la relevance feedback. ou reformulation >> ranking sinon). Plus d'exemples [ici](https://pyterrier.readthedocs.io/en/latest/rewrite.html).

# %%
# modèle DPH avant reformulation de requête
pipelineQE = pt.BatchRetrieve(index, wmodel="DPH", controls={"qemodel" : "Bo1", "qe" : "off"})
pipelineQE.search("chemical reactions")
# Out:
#     qid   docid     docno  rank      score               query
# 0     1  171636  v3blnh02     0  11.898228  chemical reactions
# 1     1  147193  ei4rb8fr     1  11.889920  chemical reactions
# 2     1   18717  iavwkdpr     2  11.688030  chemical reactions
# 3     1  170863  sj8i9ss2     3  10.143884  chemical reactions
# 4     1  121217  msdycum2     4   9.860973  chemical reactions
# ..   ..     ...       ...   ...        ...                 ...
# 995   1  154582  q4neat3x   995   4.070840  chemical reactions
# 996   1  171895  yjbcvf3o   996   4.070840  chemical reactions
# 997   1   14781  0it25j3k   997   4.067507  chemical reactions
# 998   1   70003  a1nc5k51   998   4.067507  chemical reactions
# 999   1   73765  sjod3q3j   999   4.067507  chemical reactions
#
# [1000 rows x 6 columns]

# %%
# modèle DPH après reformulation de requête
pipelineQE = pt.BatchRetrieve(index, wmodel="DPH", controls={"qemodel" : "Bo1", "qe" : "on"})
pipelineQE.search("chemical reactions")
# Out:
#     qid   docid     docno  rank      score               query
# 0     1  147193  ei4rb8fr     0  20.728032  chemical reactions
# 1     1  171636  v3blnh02     1  20.684654  chemical reactions
# 2     1   18717  iavwkdpr     2  11.160010  chemical reactions
# 3     1   20409  1g9kmpdi     3  10.702739  chemical reactions
# 4     1  170863  sj8i9ss2     4  10.347593  chemical reactions
# ..   ..     ...       ...   ...        ...                 ...
# 995   1  114233  2cxb65j1   995   3.942073  chemical reactions
# 996   1  183279  8emqwp2o   996   3.942073  chemical reactions
# 997   1   88197  f7g1zacc   997   3.941175  chemical reactions
# 998   1  178340  zsp5v8hv   998   3.938286  chemical reactions
# 999   1   60135  jx9yrpl6   999   3.938271  chemical reactions
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### Evaluation d'un système de recherche d'information
#
# Pour évaluer un système de RI, il est nécessaire d'avoir un jeu de données constitué de requêtes et de jugements de pertinence.

# %%
# exemple de 5 requêtes pour cord19
cord19.get_topics(variant='title').head(5)
# Out:
# [INFO] [starting] https://ir.nist.gov/covidSubmit/data/topics-rnd5.xml
#
# https://ir.nist.gov/covidSubmit/data/topics-rnd5.xml: 0.0%| 0.00/4.80k [00:00<?, ?B/s]
# [INFO] [finished] https://ir.nist.gov/covidSubmit/data/topics-rnd5.xml: [00:00] [18.7kB] [8.17MB/s]
#
# https://ir.nist.gov/covidSubmit/data/topics-rnd5.xml: [00:00] [18.7kB] [1.85MB/s]
#                                                                                  /usr/local/lib/python3.7/dist-packages/pyterrier/datasets.py:433: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.columns.difference(['qid','query']), 1, inplace=True)
#   qid                                    query
# 0   1                       coronavirus origin
# 1   2  coronavirus response to weather changes
# 2   3                     coronavirus immunity
# 3   4   how do people die from the coronavirus
# 4   5                animal models of covid 19

# %%
# exemple de jugements de pertinence pour les 5 premières requêtes
cord19.get_qrels().head(5)
# Out:
# [INFO] [starting] https://ir.nist.gov/covidSubmit/data/qrels-covid_d5_j0.5-5.txt
#
# https://ir.nist.gov/covidSubmit/data/qrels-covid_d5_j0.5-5.txt: 0.0%| 0.00/? [00:00<?, ?B/s]
# https://ir.nist.gov/covidSubmit/data/qrels-covid_d5_j0.5-5.txt: 0.0%| 90.1k/? [00:00<00:00, 558kB/s]
# https://ir.nist.gov/covidSubmit/data/qrels-covid_d5_j0.5-5.txt: 0.0%| 510k/? [00:00<00:00, 1.51MB/s]
# [INFO] [finished] https://ir.nist.gov/covidSubmit/data/qrels-covid_d5_j0.5-5.txt: [00:00] [1.14MB] [2.67MB/s]
#
# https://ir.nist.gov/covidSubmit/data/qrels-covid_d5_j0.5-5.txt: [00:00] [1.14MB] [2.61MB/s]
#   qid     docno  label iteration
# 0   1  005b2j4b      2       4.5
# 1   1  00fmeepz      1         4
# 2   1  010vptx3      2       0.5
# 3   1  0194oljo      1       2.5
# 4   1  021q9884      1         4

# %% [markdown]
# **Exercice 4**
#
# A partir des requêtes et des jugements de pertinence du jeu de données CORD19, Ecrire le code qui permet d'afficher les résultats de la première requête de Cord19. L'affichage fusionnera les colonnes retournées par le BatchRetriever et les colonnes des qrels (merge sur qid et docno pour rajouter label et iteration au tableau).

# %%
res1 = pt.BatchRetrieve(index, wmodel="BM25").search("coronavirus origin")
qrel = cord19.get_qrels()

res = res1.merge(qrel, on=["qid","docno"])
res
# Out:
#     qid   docid     docno  rank      score               query  label iteration
# 0     1  175892  zy8qjaai     0  11.915479  coronavirus origin      1         1
# 1     1   82224  8ccl9aui     1  11.550953  coronavirus origin      2         1
# 2     1  135326  ne5r4d4b     2  11.268729  coronavirus origin      0       1.5
# 3     1  122804  75773gwg     3  11.165944  coronavirus origin      2         5
# 4     1  122805  kn2z7lho     4  11.165944  coronavirus origin      2         3
# ..   ..     ...       ...   ...        ...                 ...    ...       ...
# 390   1   14863  8fmykb4c   974   7.214032  coronavirus origin      0       1.5
# 391   1   49386  3otc2ac1   982   7.213167  coronavirus origin      0       3.5
# 392   1  112328  iwvrpbao   986   7.213167  coronavirus origin      0       3.5
# 393   1  161733  kh06egig   992   7.205767  coronavirus origin      0         1
# 394   1  142751  v38tjof3   996   7.204584  coronavirus origin      2       1.5
#
# [395 rows x 8 columns]

# %% [markdown]
# Il existe cependant une fonction qui permet de calculer l'efficacité de ces ordonnancements au travers des métriques d'évaluation (map, précision, rappel, ndcg, ...)

# %%
pt.Experiment(
    [tfidf],
    cord19.get_topics(variant='title'),
    cord19.get_qrels(),
    eval_metrics=["map", "ndcg"])
# Out:
# /usr/local/lib/python3.7/dist-packages/pyterrier/datasets.py:433: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.columns.difference(['qid','query']), 1, inplace=True)
#          name       map      ndcg
# 0  BR(TF_IDF)  0.180002  0.370767

# %% [markdown]
# **Exercice 5**
#
# Réaliser une expérience comparant l'expansion de requêtes avec le modèle Bo1 et basé sur la KL-divergence; L'expérience est réalisée sur TREC CORD19 avec le modèle de référence BM25. Vous devrez construire des pipelines appropriées (plus de détails sur [l'expansion](https://pyterrier.readthedocs.io/en/latest/rewrite.html) et les [expérimentations](https://pyterrier.readthedocs.io/en/latest/experiments.html)).
#
# Quelles approches entraînent des augmentations significatives de NDCG et MAP ou autres métriques ?

# %%
bm25 = pt.BatchRetrieve(index, wmodel="BM25")
bo1 = pt.rewrite.Bo1QueryExpansion(index)

pipe1 = bm25
pipe2 = bm25 >> bo1 >> bm25
pt.Experiment(
    [pipe1, pipe2],
    cord19.get_topics(variant='title'),
    cord19.get_qrels(),
    eval_metrics=["map", "ndcg"])
# Out:
# /usr/local/lib/python3.7/dist-packages/pyterrier/datasets.py:433: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.columns.difference(['qid','query']), 1, inplace=True)
#                                                                                                    name  ...      ndcg
# 0                                                                                              BR(BM25)  ...  0.373328
# 1  Compose(Compose(BR(BM25), <pyterrier.rewrite.Bo1QueryExpansion object at 0x7f0d9f89c550>), BR(BM25))  ...  0.388397
#
# [2 rows x 3 columns]
