# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/PLDAC/
# !pip install python-terrier
#!pip install -r trec-cast-tools-master/src/main/python/requirements.txt
#!python trec-cast-tools-master/src/main/python/kilt_trecweb.py mini_corpus/KILT/kilt_9000.json mini_corpus/KILT/
#!python trec-cast-tools-master/src/main/python/marco_trecweb.py mini_corpus/MARCO/marco_14000_doc.tsv mini_corpus/MARCO/ mini_corpus/MARCO/marco_duplicates.txt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyterrier as pt
import re
if not pt.started():
    pt.init()
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/PLDAC
# ...
#      |████████████████████████████████| 97 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 40.0 MB/s
# ...
#      |████████████████████████████████| 69 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 255 kB 51.4 MB/s
# ...
#      |████████████████████████████████| 41 kB 238 kB/s
# ...
#      |████████████████████████████████| 1.2 MB 45.4 MB/s
# ...
#      |████████████████████████████████| 294 kB 51.3 MB/s
# ...
#      |████████████████████████████████| 6.4 MB 35.5 MB/s
# ...
#      |████████████████████████████████| 126 kB 54.2 MB/s
# ...
#      |████████████████████████████████| 72 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 46.6 MB/s
# ...
#      |████████████████████████████████| 291 kB 67.2 MB/s
# ...
#      |████████████████████████████████| 59 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 45 kB 2.2 MB/s
# ...

# %%
#marco_indexer = pt.TRECCollectionIndexer('./mini_corpus/MARCO/marco_14000_doc.tsv.index')
#marcoref = marco_indexer.index('./mini_corpus/MARCO/marco_14000_doc.tsv.trecweb')
marcoref = './mini_corpus/MARCO/marco_14000_doc.tsv.index'
marco_index = pt.IndexFactory.of(marcoref)
print(marco_index.getCollectionStatistics().toString())
# Out:
# Number of documents: 13878
# Number of terms: 311471
# Number of postings: 4008339
# Number of fields: 0
# Number of tokens: 9847582
# Field names: []
# Positions:   false

# %%
#kilt_indexer = pt.TRECCollectionIndexer('./mini_corpus/KILT/kilt_9000.index')
#kiltref = kilt_indexer.index('./mini_corpus/KILT/kilt_9000.trecweb')
kiltref = "./mini_corpus/KILT/kilt_9000.index"
kilt_index = pt.IndexFactory.of(kiltref)
print(kilt_index.getCollectionStatistics().toString())
# Out:
# Number of documents: 9000
# Number of terms: 166580
# Number of postings: 2305364
# Number of fields: 0
# Number of tokens: 4829407
# Field names: []
# Positions:   false

# %%
#df_marco_p = pd.read_csv('./mini_corpus/MARCO/marco_300000_passage.tsv',sep='\t',names=['docno','text'],dtype=str)
#marcop_indexer = pt.DFIndexer('./mini_corpus/MARCO/marco_300000_passage.index')
#marcopref = marcop_indexer.index(df_marco_p['text'],df_marco_p['docno'])
marcopref = './mini_corpus/MARCO/marco_300000_passage.index'
marcop_index = pt.IndexFactory.of(marcopref)
print(marcop_index.getCollectionStatistics().toString())
# Out:
# Number of documents: 300000
# Number of terms: 144137
# Number of postings: 7207945
# Number of fields: 0
# Number of tokens: 9628211
# Field names: []
# Positions:   false

# %%
mk_indexer = pt.TRECCollectionIndexer('./mini_corpus/mk.index')
mkref = mk_indexer.index(['./mini_corpus/KILT/kilt_9000.trecweb','./mini_corpus/MARCO/marco_14000_doc.tsv.trecweb'])
#mkref = './mini_corpus/mk.index'
mk_index = pt.IndexFactory.of(mkref)
print(mk_index.getCollectionStatistics().toString())
# Out:
# Number of documents: 22878
# Number of terms: 408390
# Number of postings: 6313703
# Number of fields: 0
# Number of tokens: 14676989
# Field names: []
# Positions:   false

# %%
marcop_dev_queries = pd.read_csv('./data/marco_passage/queries.dev.tsv', sep='\t', names=['qid', 'query'], dtype=str)
marcop_dev_queries['query'] = marcop_dev_queries['query'].apply(lambda x: re.sub(r'[^A-Za-z0-9]',' ',x))
marcop_dev_qrels = pd.read_csv('./data/marco_passage/qrels.dev.tsv', sep='\t', names=['qid','_','docno', 'label'], dtype= {'qid': str, 'docno': str, 'label': int}).drop(columns=['_'])

bm25_marcop = pt.BatchRetrieve(marcop_index, wmodel="BM25")
#tfidf_marcop = pt.BatchRetrieve(marcop_index, wmodel="TF_IDF")

pt.Experiment(
    [bm25_marcop],
    #[tfidf_marcop,bm25_marcop],
    topics=marcop_dev_queries,
    qrels=marcop_dev_qrels,
    eval_metrics=["map","recip_rank"]
)

# %% [markdown]
# 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

# %%
# !git remote set-url origin https://nam685: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@github.com/nam685/PLDAC.git

# %%
# !git config --global user.email "lehainam2371999@gmail.com"
# !git config --global user.name "NamLe"
# !git add .
# !git commit -m "mk_index_both"
# !git push
# Out:
# [main f3b86c9] mk_index_both
#  1 file changed, 1 insertion(+), 1 deletion(-)
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://nam685: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@github.com/nam685/PLDAC.git/'

# %%
# !git log
# Out:
# commit f674a6bfdde69346736d619570e829a656eeb660 (HEAD -> main)
# Author: NamLe <lehainam2371999@gmail.com>
# Date:   Mon Feb 21 09:02:12 2022 +0000
#
#     mk_index_both
#
# commit 53aa979a8b3a05196e0f008f4b04ec22b6b16edf (origin/main, origin/HEAD)
# Author: NamLe <lehainam2371999@gmail.com>
# Date:   Sun Feb 20 16:29:25 2022 +0000
#
#     cleartrash
#
# commit 9063cf9b25f011655890c5d081f3918970706e92
# Author: NamLe <lehainam2371999@gmail.com>
# Date:   Sun Feb 20 15:48:52 2022 +0000
#
#     separate_index
#
# commit 3ffc9dbc00541ad1e8237057196bb69ed917a902
# Author: NamLe <lehainam2371999@gmail.com>
# Date:   Sun Feb 20 13:10:40 2022 +0000
#
#     logbook
#
# commit a7d22a919022b7258afd5cf5e11c0815d16262a5
# Author: Nam Le <lehainam2371999@gmail.com>
# Date:   Sun Feb 20 13:51:14 2022 +0100
#
#     marco_corpus_mini
#
# commit 0ee55d087dd1a8216cebf395a280418d8d111726
# Author: Nam Le <lehainam2371999@gmail.com>
# Date:   Sat Feb 19 21:27:48 2022 +0100
#
#     marco_data
#
# ...
