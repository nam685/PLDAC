# %%
#!pip install python-terrier
#!pip install -r trec-cast-tools-master/src/main/python/requirements.txt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyterrier as pt
import re
if not pt.started():
    pt.init()
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/PLDAC/
#!python trec-cast-tools-master/src/main/python/kilt_trecweb.py mini_corpus/KILT/kilt.json mini_corpus/KILT/

# %%
git config --global user.email "lehainam2371999@example.com"
git config --global user.name "Your Name"
# !git add .
# !git commit -m "format_index_KILT"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@a7d6b4ec7fbf.(none)')

# %%
kilt_indexer = pt.TRECCollectionIndexer('./mini_corpus/KILT/kilt.index')
kiltref = kilt_indexer.index('./mini_corpus/KILT/kilt.json.trecweb')

# %%
kilt_index = pt.IndexFactory.of(kiltref)
print(kilt_index.getCollectionStatistics().toString())
# Out:
# Number of documents: 9000
# Number of terms: 166580
# Number of postings: 2305364
# Number of fields: 0
# Number of tokens: 4829407
# Field names: []
# Positions:   false
