# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/PLDAC/
# !pip install python-terrier
# !pip install -r trec-cast-tools-master/src/main/python/requirements.txt
#!python trec-cast-tools-master/src/main/python/kilt_trecweb.py mini_corpus/KILT/kilt.json mini_corpus/KILT/
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyterrier as pt
import re
if not pt.started():
    pt.init()

# %%
# !git pull
# Out:
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 2), reused 15 (delta 2), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
kilt_indexer = pt.TRECCollectionIndexer('./mini_corpus/KILT/kilt.index')
kiltref = kilt_indexer.index('./mini_corpus/KILT/kilt.json.trecweb')

# %%
kilt_index = pt.IndexFactory.of(kiltref)
print(kilt_index.getCollectionStatistics().toString())
# Out:
# Number of documents: 9000
# Number of terms: 166580
# Number of postings: 2305364
# Number of fields: 0
# Number of tokens: 4829407
# Field names: []
# Positions:   false

# %%
marco_dev_queries = pd.read_csv('./data/marco/queries.docdev.tsv', sep='\t', names=['qid', 'query'], dtype=str)
marco_dev_queries['query'] = marco_dev_queries['query'].apply(lambda x: re.sub(r'[^A-Za-z0-9]',' ',x))
marco_dev_qrels = pd.read_csv('./data/marco/msmarco-docdev-qrels.tsv', sep=' ', names=['qid','_','docno', 'label'], dtype= {'qid': str, 'docno': str, 'label': int}).drop(columns=['_'])

#bm25_marco = pt.BatchRetrieve(marco_index, wmodel="BM25")
#tfidf_marco = pt.BatchRetrieve(marco_index, wmodel="TF_IDF")

#pt.Experiment(
#    [tfidf_marco,bm25_marco],
#    topics=marco_dev_queries,
#    qrels=marco_dev_qrels,
#    eval_metrics=["map","recip_rank"]
#)
